# %%
from opensearchpy import OpenSearch
from opensearch_dsl import Search
import pandas as pd

# %%
from streamlit_chat import config
NCP_CONFIG = config.NCP_CONFIG
EMB_CONFIG = config.HCX_EMBEDDING
OSH_CONFIG = config.OPENSEARCH
EMB_MODEL_NAME = "clir-sts-dolphin"

# %%
host = OSH_CONFIG['HOST']
port = 9200
auth = (OSH_CONFIG['ID'], OSH_CONFIG['PASSWD'])

# %%
client = OpenSearch(
    hosts=[{'host': host, 'port': port}],
    http_compress = True, # enables gzip compression for request bodies
    http_auth = auth,
    use_ssl = True,
    verify_certs = False,
    ssl_assert_hostname = False,
    ssl_show_warn = False,
    timeout = 300
)

# %%
index_name = "ncp_edu_sc2-emb-test-index"
index_body = {
  "settings": {
    "index": {
      "knn": True,
      "knn.algo_param.ef_search": 100
    }
  },
  "mappings": {
    "properties": {
        "origin-question":{
            "type": "text"
        },
        "origin-text":{
            "type": "text"
        },
        ("emb-model--" + EMB_MODEL_NAME): {
            "type": "text"
        },
        "vector": {
          "type": "knn_vector",
          "dimension": 1024,
          "method": {
            "name": "hnsw",
            "space_type": "cosinesimil",
            "engine": "nmslib",
            "parameters": {
              "ef_construction": 128,
              "m": 24
            }
          }
        }
    }
  }
}

# %%
response = client.indices.create(index=index_name, body=index_body)

# %%
from streamlit_chat.modules.HyperClovaX import HyperClovaX
hcx = HyperClovaX(clova_studio_api_key=EMB_CONFIG['X-NCP-CLOVASTUDIO-API-KEY'], apigw_api_key=EMB_CONFIG['X-NCP-APIGW-API-KEY'])
hcx.set_embedding(app_id=EMB_CONFIG['APP_ID'], model_name=EMB_MODEL_NAME)

# %%
df_csv = pd.read_csv(filepath_or_buffer='streamlit_chat/data/starcraft2.csv')

# %%
origin_question = []
origin_text = []
embedding_text = []
# print(len(df['Completion']))
for idx, line in df_csv.iterrows():
    print(f"{idx + 1} / {len(df_csv['Completion'])}")
    res = hcx.embedding(text = line['Completion'])
    if res.status_code == 200:
        embedding_result = res.json()['result']['embedding']
        origin_question.append(line['Text'])
        origin_text.append(line['Completion'])
        embedding_text.append(embedding_result)
    else:
        print(f'error : {line["Completion"]}')
# Out:
# 1 / 246
# 2 / 246
# 3 / 246
# 4 / 246
# 5 / 246
# 6 / 246
# 7 / 246
# 8 / 246
# 9 / 246
# 10 / 246
# 11 / 246
# 12 / 246
# 13 / 246
# 14 / 246
# 15 / 246
# 16 / 246
# 17 / 246
# 18 / 246
# 19 / 246
# 20 / 246
# 21 / 246
# 22 / 246
# 23 / 246
# 24 / 246
# 25 / 246
# 26 / 246
# 27 / 246
# 28 / 246
# 29 / 246
# 30 / 246
# 31 / 246
# 32 / 246
# 33 / 246
# 34 / 246
# 35 / 246
# 36 / 246
# 37 / 246
# 38 / 246
# 39 / 246
# 40 / 246
# 41 / 246
# 42 / 246
# 43 / 246
# 44 / 246
# 45 / 246
# 46 / 246
# 47 / 246
# 48 / 246
# 49 / 246
# 50 / 246
# 51 / 246
# 52 / 246
# 53 / 246
# 54 / 246
# 55 / 246
# 56 / 246
# 57 / 246
# 58 / 246
# 59 / 246
# 60 / 246
# 61 / 246
# 62 / 246
# 63 / 246
len(df_final)
# Out:
# 246

# %%
## bulk insert
sc2_datas = []
for idx, line in df_final.iterrows():
    # print(line['origin_text'])
    # index_no = '{ "index" : { "_index" : "' + index_name + '", "_id" : "' + str(idx + 1) + '" } }'
    # data = '{ "origin-text": "' + line['origin_text'] + '", "sc2-vector": ' + str(line['embedding_text']) + ' }'
    
    index_no = { "index" : { "_index" : index_name, "_id" : (idx + 1)} }
    data =  {"origin-question": line['origin-question'], "origin-text": line['origin_text'], "vector": line['embedding_text']}
    sc2_datas.append(index_no)
    sc2_datas.append(data)

# %%
client.bulk(sc2_datas)
# Out:
# {'took': 354,
#  'errors': False,
#  'items': [{'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '1',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '2',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 1,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '3',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 2,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 3,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '5',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '6',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 5,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '7',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 6,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '8',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 7,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 8,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '10',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 9,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '11',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 10,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '12',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 11,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '13',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 12,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '14',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 13,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '15',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 14,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '16',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 15,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '17',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 16,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '18',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 17,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '19',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 18,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '20',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 19,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '21',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 20,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '22',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 21,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '23',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 22,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '24',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 23,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '25',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 24,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '26',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 25,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '27',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 26,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '28',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 27,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '29',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 28,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '30',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 29,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '31',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 30,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '32',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 31,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '33',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 32,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '34',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 33,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '35',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 34,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '36',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 35,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '37',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 36,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '38',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 37,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '39',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 38,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '40',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 39,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '41',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 40,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '42',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 41,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '43',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 42,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '44',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 43,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '45',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 44,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '46',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 45,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '47',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 46,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '48',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 47,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '49',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 48,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '50',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 49,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '51',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 50,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '52',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 51,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '53',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 52,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '54',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 53,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '55',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 54,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '56',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 55,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '57',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 56,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '58',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 57,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '59',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 58,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '60',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 59,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '61',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 60,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '62',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 61,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '63',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 62,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '64',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 63,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '65',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 64,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '66',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 65,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '67',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 66,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '68',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 67,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '69',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 68,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '70',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 69,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '71',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 70,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '72',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 71,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '73',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 72,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '74',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 73,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '75',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 74,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '76',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 75,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '77',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 76,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '78',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 77,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '79',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 78,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '80',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 79,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '81',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 80,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '82',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 81,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '83',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 82,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '84',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 83,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '85',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 84,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '86',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 85,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '87',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 86,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '88',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 87,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '89',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 88,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '90',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 89,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '91',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 90,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '92',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 91,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '93',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 92,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '94',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 93,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '95',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 94,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '96',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 95,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '97',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 96,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '98',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 97,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '99',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 98,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '100',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 99,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '101',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 100,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '102',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 101,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '103',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 102,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '104',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 103,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '105',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 104,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '106',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 105,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '107',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 106,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '108',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 107,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '109',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 108,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '110',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 109,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '111',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 110,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '112',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 111,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '113',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 112,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '114',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 113,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '115',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 114,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '116',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 115,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '117',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 116,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '118',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 117,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '119',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 118,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '120',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 119,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '121',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 120,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '122',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 121,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '123',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 122,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '124',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 123,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '125',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 124,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '126',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 125,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '127',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 126,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '128',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 127,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '129',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 128,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '130',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 129,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '131',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 130,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '132',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 131,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '133',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 132,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '134',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 133,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '135',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 134,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '136',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 135,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '137',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 136,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '138',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 137,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '139',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 138,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '140',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 139,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '141',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 140,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '142',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 141,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '143',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 142,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '144',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 143,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '145',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 144,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '146',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 145,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '147',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 146,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '148',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 147,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '149',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 148,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '150',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 149,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '151',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 150,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '152',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 151,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '153',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 152,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '154',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no':
# %%
## Text Search
search_body_text_t = {
  "size": 10,
  "query": {
    "match": {
      "origin_text": query_text
    }
  }
}
search_result_text_t = client.search(index=index_name, body=search_body_text_t)
print(len(search_result_text_t["hits"]["hits"]))
for s_text_t in search_result_text_t["hits"]["hits"]:
    print(s_text_t)
    print(f"{s_text_t['_score']} | {s_text_t['_source']['origin-text']}")
# Out:
# 0

# %%
## Text Search
search_body_text_q = {
  "size": 10,
  "query": {
    "match": {
      "origin-question": query_text
    }
  }
}
search_result_text_q = client.search(index=index_name, body=search_body_text_q)
print(len(search_result_text_q["hits"]["hits"]))
for s_text_q in search_result_text_q["hits"]["hits"]:
    print(s_text_q)
    print(f"{s_text_q['_score']} | {s_text_q['_source']['origin-text']}")
# Out:
# 5
# {'_index': 'ncp_edu_sc2-emb-test-index', '_id': '25', '_score': 4.6622844, '_source': {'origin-question': '불곰의 정보', 'origin-text': '불곰(Marauder)는 테란의 중돌격 보병 유닛 입니다. 응징자 유탄(Punisher Grenades)로 적을 공격하며, 중장갑 상대의 적에게 보다 큰 피해를 입힙니다.\n병영에 부착된 기술실에서 충격탄(Concussive Shells) 연구가 완료되면, 불곰의 응징자 유탄이 적을 일시적으로 느리게 만듭니다. (거대 유닛은 면역)', 'vector': [0.033098537, -0.08931482, -1.4836656, 0.010223052, -0.98053813, 0.17101067, 0.11375199, 1.5409106, 1.6841818, 1.1990383, 0.09654522, 0.5535445, -0.40943304, -1.6992675, 0.8703241, 1.1222498, -0.29309046, -0.2309394, -0.9467727, 0.48505932, 0.20260587, -0.48926398, -0.09958619, -1.1269984, 0.8225925, 0.8436089, -0.06530215, -0.6061037, -0.7801258, 2.1128008, -0.19166678, -0.21952447, -1.3833954, 0.4410267, -0.7162656, -1.3868091, 1.127666, -0.77503186, -1.0052383, 0.1423569, -0.017801268, -0.7798249, 0.6277135, -1.0047272, 2.545027, 0.27202564, -0.7667862, -1.7197127, -0.16584398, 0.23476714, -1.6042755, -0.46989933, -1.9913551, 1.4773569, 1.5619156, 0.37501574, -0.7663298, 0.322562, -0.82670695, -1.1531631, 0.25238195, 0.6689789, -0.0062610465, 0.47740903, 0.2363774, -0.36224207, 1.0405197, -0.08428231, -0.53413796, 1.3853806, -0.07854486, 0.8163064, -0.7341547, -1.679975, -1.1467295, 0.3563669, -0.17406307, 0.07066159, -1.1199877, -0.578548, 0.4022443, 0.07983448, 0.4160228, -0.4043838, -0.5257181, 1.0896062, 0.6844806, -0.9692616, 0.77299976, 0.57459795, -0.33908653, 1.1494081, 1.5735683, -0.52990115, -0.15195355, -0.74465686, 0.9572948, 4.98936, -1.5358213, 0.48601937, 1.8439786, -0.82479995, 0.014260708, 0.37772936, -0.88176614, 0.07648958, 0.67785436, -0.12796943, -1.842397, 1.1740803, -1.2881646, 0.35795248, -0.6408793, -1.1801575, -0.4924713, -0.66240877, 0.7973588, -0.5312247, -0.07696275, -0.76503116, -0.31129918, -1.0283017, -0.080221176, 
0.12845016, 2.4760213, 0.5035064, -0.97602934, 0.08593767, 0.49207526, -0.7460963, 0.74675345, 1.243846, -1.1237857, -0.2764205, -1.2541844, -0.8255889, -0.60395145, 0.39535844, -0.086410716, 0.8584635, -1.7884686, -0.25653446, 0.7282181, -1.7038575, 0.06625117, -0.08118867, 0.2916149, 0.22607419, 0.6558062, -1.1214052, -0.09298879, -0.11796145, -1.3822418, -0.3078516, -0.23158537, -1.243875, 0.5932144, 0.9063484, -1.06097 ...
# 3.654149 | 스타크래프트2에 등장하는 불곰(Marauder)은 테란의 중돌격 보병으로 응진자 유탄(Punisher Grenades)을 사용하며, 중장갑 상대의 적에게 큰 피해를 입히는 보병 유닛 입니다.
# 높은 체력을 보유하고 있어 체력이 낮은 해병을 보호하며 전투가 가능합니다.

# %%
## Normal KNN
search_body = {
  "size": 15,
  "query": {
    "knn": {
      "vector": {
        "vector": query_text_emb,
        "k": 15
      }
    }
  }
}
search_result = client.search(index=index_name, body=search_body)
print(len(search_result["hits"]["hits"]))
for s in search_result["hits"]["hits"]:
    print(f"{s['_score']} | {s['_source']['origin-text']}")
# Out:
# 15
# 0.7754099 | 스타크래프트2에 등장하는 불곰(Marauder)은 테란의 중돌격 보병으로 응진자 유탄(Punisher Grenades)을 사용하며, 중장갑 상대의 적에게 큰 피해를 입히는 보병 유닛 입니다.
# 높은 체력을 보유하고 있어 체력이 낮은 해병을 보호하며 전투가 가능합니다.
# 0.76708484 | 불곰(Marauder)는 테란의 중돌격 보병 유닛 입니다. 응징자 유탄(Punisher Grenades)로 적을 공격하며, 중장갑 상대의 적에게 보다 큰 피해를 입힙니다.
# 병영에 부착된 기술실에서 충격탄(Concussive Shells) 연구가 완료되면, 불곰의 응징자 유탄이 적을 일시적으로 느리게 만듭니다. (거대 유닛은 면역)
# 0.76502085 | 화염 기갑병은 하나의 기본 능력이 존재합니다.
# - 화염차 모드 : 화염 기갑병을 기동력이 높은 화염차로 변신시킵니다. 화염차는 일직선의 화염 공격을 합니다.
# 0.75396264 | 불곰은 높은 체력을 보유하고 있지만 지상 공격만 가능하여, 해병 부대와 조합하여 사용하는 것이 좋습니다.
# - 생명력 : 125
# - 방어력 : 1(+1)
# - 특성 : 중장갑-생체
# 0.7460867 | 화염차는 낮은 체력을 보유했지만 빠른 기동성으로 적들에게 혼란을 주기 좋고, 정찰 및 게릴라에 특화되어 있습니다. 또한 화염기갑병(Hellbat)으로 변신하여 생명력을 약간 높이고 공격력을 크게 증가시킬 수 있습니다.
# 0.7310183 | 화염차는 한가지 기본 능력이 존재합니다.
# - 화염 기갑병 모드 : 화염차를 근거리 전투 유닛인 화염 기갑병으로 변신시킵니다. 화염 기갑병은 전방에 작은 부채꼴 형태의 화염 공격을 합니다.
# 0.72997224 | 불곰에 적용 가능한 업그레이드는 4가지가 있습니다.
# - 전투 자극제 사용(Use Stimpack) : 몇 초 동안 이동 및 공격속도를 크게 향상스키지만, 사용 즉시 생명력 20을 잃습니다.
# - 충격탄(Concussive Shells) : 불곰이 명중시킨 대상의 움직임이 일시적으로 느려집니다. (거대 유닛은 면역)
# - 보병 무기 업그레이드 1, 2, 3 단계 : 불곰의 공격력을 증가시킵니다.
# - 보병 장갑 업그레이드 1, 2, 3 단계 : 불곰의 방어력을 증가시킵니다.
# 0.72827816 | 불곰에 적용할 수 있는 업그레이드는 아래와 같습니다.
# - 전투 자극제 사용(Use Stimpack) : 병영의 부착된 기술실에서 연구 가능합니다. 불곰이 사용할 경우 즉시 20의 피해를 입지만, 몇 초 동안 이동속도와 공격속도를 크게 향상시킵니다.
# - 충격탄(Concussive Shells) : 병영의 부착된 기술실에서 연구 가능합니다. 불곰의 기본 공격에 적중한 적 유닛을 일시적으로 느리게 만듭니다. 거대 유닛은 면역입니다.
# - 보병 무기 업그레이드 1, 2, 3 단계 : 공학 연구소에서 연구 가능합니다. 불곰의 공격력을 증가시키는 업그레이드 입니다.
# - 보병 장갑 업그레이드 1, 2, 3 단계 : 공학 연구소에서 연구 가능합니다. 불곰의 방어력을 증가시킵니다.
# 0.7230016 | 불곰은 응징자 유탄(Punisher Grenades)를 사용하여 적을 공격하며 중장갑 상대의 적에게 보다 큰 피해를 입힙니다.
# - 공격력 : 10(+1) / 중장갑 상대 : 20(+2)
# - 사거리 : 6
# - 공격 속도 : 1.5 --> 1(전투 자극제 사용)
# - 대상 : 지상 목표물
# 0.7219566 | 전투자극제는 스타크래프트2에 등장하는 해병과 불곰이 사용할 수 있는 능력 입니다. 병영의 부착된 기술실에서 전투 자극제 사용 연구가 완료되면 해병과 불곰은 전투 자극제 사용 능력을 사용할 수 있습니다. 몇 초 동안 이동 및 공격속도를 크게 향상시키지만, 해병의 체력에 10, 불곰의 체력에 20의 피해를 입힙니다.
# 0.71524 | 화염기갑병(Hellbat)은 화염차가 돌격 모드로 변신한 지상 유닛입니다.. 군수공장에서 바로 생산할 수도 있습니다.
# 화염차보다 느린 기동력을 가졌지만 경장갑 상대로 매우 큰 피해를 입히므로 본대와 함께 전투를 수행합니다.
# 0.7046835 | 충격탄은 스타크래프트2에 등장하는 테란 유닛인 불곰에게 적용할 수 있는 추가 연구 입니다. 병영의 부착된 기술실에서 충격탄 연구가 완료되면 불곰의 공격에 명중한 대상의 움직임이 일시적으로 느려집니다. 거대 유닛은 충격탄 효과에 면역입니다.
# 0.7009596 | 불곰이 보유한 기본 능력은 존재하지 않습니다.
# 0.6945998 | 화염차가 사용 가능한 업그레이드는 4가지가 있습니다.
# - 지옥불 조기점화기 : 화염차가 경장갑 유닛에게 5의 추가 피해를 입힙니다.
# - 지능형 제어장치 : 화염차가 화염기갑병으로 빠르게 변환합니다.
# - 차량 무기 업그레이드 1, 2, 3 단계 : 화염차의 공격력을 증가시킵니다.
# - 차량 및 우주선 장갑 업그레이드 1, 2, 3 단계 : 화염차의 방어력을 증가시킵니다.
# 0.6884291 | 화염차(Hellion)은 스타크래프트2에 등장하는 테란의 지상 정찰 및 전략 유닛 입니다. 빠른 기동성과 경장갑 상대의 높은 공격력으로 상대 를 혼란에 빠트릴 수 있습니다.

# %%
query_text = "바이킹의 공격력을 알려주세요"
query_text_emb = hcx.embedding(text=query_text)
query_text_emb = query_text_emb.json()['result']['embedding']

## Hybrid Search
search_body = {
  "_source": {
    "exclude": [
      "vector"
    ]
  },
  "query": {
    "hybrid": {
      "queries": [
        {
          "match": {
            "origin-question": {
              "query": query_text
            }
          }
        },
        {
          "match": {
            "origin_text": {
              "query": query_text
            }
          }
        },
        {
          "knn": {
            "vector": {
              "vector": query_text_emb,
              "k": 10
            }
          }
        }
      ]
    }
  },"size":10,
  "search_pipeline" : {
      "phase_results_processors": [
      {
        "normalization-processor": {
          "normalization": {
            "technique": "min_max"
          },
          "combination": {
            "technique": "arithmetic_mean",
            "parameters": {
              "weights": [
                0.2,
                0.1,
                0.7
              ]
            }
          }
        }
      }
    ]
  }
}
print(index_name)
# search_params = {
#     "search_pipeline" : "cw-nlp-search-pipeline"
# }
#search_result = client.search(index=index_name, body=search_body, params=search_params)

search_result = client.search(index=index_name, body=search_body)
print(len(search_result["hits"]["hits"]))
for s in search_result["hits"]["hits"]:
    print(f"{s['_score']} | {s['_source']['origin-text']}")
# Out:
# ncp_edu_sc2-emb-test-index
# 10
# 0.7359637 | 바이킹은 높은 체력을 가진 기계 유닛으로 다양한 목적으로 사용 가능합니다.
# - 생명력 : 135
# - 방어력 : 0(+1)
# - 특성 : 중장갑-기계
# 0.7 | 바이킹은 3가지 적용 가능한 업그레이드가 있습니다.
# - 지능형 제어 장치 : 바이킹의 전투 모드를 빠르게 전환합니다.
# - 우주선 무기 업그레이드 1, 2, 3 단계 : 바이킹의 공격력을 증가시킵니다.
# - 차량 및 우주선 장갑 업그레이드 1, 2, 3 단계 : 바이킹의 방어력을 증가시킵니다.
# 0.67833734 | 바이킹은 두가지 기본 능력이 존재합니다.
# - 돌격 모드 : 바이킹을 돌격 모드로 전환합니다. 지상으로 이동하며 지상 목표물만 공격합니다.
# - 전투기 모드 : 바이킹을 전투기 모드로 전환합니다. 공중으로 이동하며 공중 목표물만 공격합니다.
# 0.62398934 | 바이킹의 공격 능력은 아래와 같습니다.
#
# 랜저 유도탄(Lanzer Torpedoes)을 사용하는 공중 공격 모드(전투기 모드)
# - 공격력 : 10(+1) x 2 / 중장갑 상대 : 14(+1) x 2
# - 사거리 : 9
# - 공격 속도 : 2(아주빠름 1.43)
# - 대상 : 공중 목표물
#
# 개틀링 포(Gatling Cannon)을 사용하는 지상 공격 모드(돌격 모드)
# - 공격력 : 12(+1) / 기계 상대 : 20(+2)
# - 사거리 : 6
# - 공격 속도 : 1(아주 빠름 기준 0.71)
# - 대상 : 지상 목표물
# 0.54111195 | 바이킹(Viking)은 스타크래프트2에 등장하는 테란 공중 유닛 입니다. 공중을 공격할 수 있는 전투기 모드와, 지상에 내려와 지상 유닛을 공격할 수 있는 돌격 모드 전환이 가능합니다.
# 0.28512767 | 스타크래프트2에 등장하는 테란 공중유닛 정보를 알려드리겠습니다.
# - 바이킹(Viking) : 튼튼한 전투 지원기 입니다. 강력한 대주력함 공중 미사일을 탑재하고 있습니다. 돌격 모드로 변신하여 지상에 내려와 지상 유닛을 공격할 수 있습니다.
# - 벤시(Banshee) : 전술 타격기입니다. 은폐 업그레이드를 사용하여 은폐가 가능합니다.
# - 밤까마귀(Raven) : 공중 지원 유닛입니다. 자동 포탑 설치, 방해 매트릭스, 대장갑 미사일을 사용할 수 있습니다.
# - 의료선(Medivac) : 공중 수송기입니다. 주위 생체 유닛을 치료하며, 재연소 장치를 사용하여 빠른 이동이 가능합니다.
# - 전투순양함(Battlecruiser) : 강력한 군함입니다. 야마토 포와 전술 차원 도약을 사용할 수 있습니다.
# 0.18065141 | 반응로를 부착하면 유닛을 동시에 두기씩 생산할 수 있습니다.
#
# 병영 반응로
# - 해병, 사신 생산 가능
#
# 군수공장 반응로
# - 화염차, 화염기갑병, 땅거미지뢰 생산 가능
#
# 우주공항 반응로
# - 바이킹, 의료선, 해방선 생산 가능
# 0.042816266 | 밴시는 은폐를 사용하여 적의 공격을 회피할 수 있습니다. 다만 공중 공격은 불가능 하므로, 바이킹과 같은 호위 유닛이 필요합니다.
# - 생명력 : 140
# - 방어력 : 0(+1)
# - 특성 : 경장갑-기계
# 0.03794456 | 기술실을 부착할 경우 가능한 기능들을 자세히 알려드리겠습니다.
#
# 병영 기술실
# - 전투 방패 연구 : 해병의 체력이 10만큼 증가합니다.
# - 전투 자극제 연구 : 해병과 불곰이 전투 자극제를 사용할 수 있습니다. 전투 자극제를 사용한 유닛은 체력 피해를 빋지만, 짧은 시간 동안 공격 및 이동 속도가 증가합니다.
# - 충격탄 연구 : 대상의 움직임이 느려지도록 불곰의 무기를 업그레이드 합니다. 거대 유닛은 면역입니다.
# - 불곰 생산 : 병영에서 불곰의 생산이 가능해집니다.
# - 유령 생산 : 병영에서 유령의 생산이 가능해집니다. (유령 사관학교 필요)
#
# 군수 공장 기술실
# - 지옥불 조기점화기 연구 : 화염차가 경장갑 유닛에게 5의 추가 피해를 입힙니다. 화염기갑병이 경장갑 유닛에게 12의 추가 피해를 입힙니다.
# - 허리케인 추진기 연구 : 사이클론의 이도속도를 20% 향상시킵니다.
# - 천공 발톱 연구 : 땅거미 지뢰의 잠복 및 활성화 시간이 3배 더 빨라집니다.
# - 지능형 제어 장치 연구 : 화염차, 화염기갑병, 바이킹, 토르가 전투 모드를 빠르게 전환합니다.
# - 공성전차 생산 : 군수공장에서 밴시 생산이 가능해집니다.
# - 토르 생산 : 군수공장에서 토르 생산이 가능해집니다. (무기고 필요)
# - 사이클론 생산 : 군수공장에서 사이클론 생산이 가능해집니다.
#
# 우주공항 기술실
# - 은폐장 연구 : 밴시가 은폐 능력을 사용할 수 있습니다.
# - 초비행 회전날개 연구 : 밴시의 이동 속도가 증가합니다.
# - 방해 매트릭스 연구 : 밤까마귀가 방해 매트릭스를 사용할 수 있습니다.
# - 밴시 생산 : 우주공항에서 밴시 생산이 가능해집니다.
# - 밤까마귀 생산 : 우주공항에서 밤까마귀 생산이 가능해집니다.
# - 전투순양함 생산 : 우주공항에서 전투순양함 생산이 가능해집니다.(융합로 필요)
# 0.00070000003 | 화염 기갑병은 하나의 기본 능력이 존재합니다.
# - 화염차 모드 : 화염 기갑병을 기동력이 높은 화염차로 변신시킵니다. 화염차는 일직선의 화염 공격을 합니다.
