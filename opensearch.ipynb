# %%
from opensearchpy import OpenSearch
from opensearch_dsl import Search
import pandas as pd

# %%
from streamlit_chat import config
NCP_CONFIG = config.NCP_CONFIG
EMB_CONFIG = config.HCX_EMBEDDING
OSH_CONFIG = config.OPENSEARCH
EMB_MODEL_NAME = "clir-sts-dolphin"

# %%
host = OSH_CONFIG['HOST']
port = 9200
auth = (OSH_CONFIG['ID'], OSH_CONFIG['PASSWD'])

# %%
client = OpenSearch(
    hosts=[{'host': host, 'port': port}],
    http_compress = True, # enables gzip compression for request bodies
    http_auth = auth,
    use_ssl = True,
    verify_certs = False,
    ssl_assert_hostname = False,
    ssl_show_warn = False,
    timeout = 300
)

# %%
index_name = "ncp_edu_sc2-emb-test-index"
index_body = {
  "settings": {
    "index": {
      "knn": True,
      "knn.algo_param.ef_search": 100
    }
  },
  "mappings": {
    "properties": {
        "origin-question":{
            "type": "text"
        },
        "origin-text":{
            "type": "text"
        },
        ("emb-model--" + EMB_MODEL_NAME): {
            "type": "text"
        },
        "vector": {
          "type": "knn_vector",
          "dimension": 1024,
          "method": {
            "name": "hnsw",
            "space_type": "cosinesimil",
            "engine": "nmslib",
            "parameters": {
              "ef_construction": 128,
              "m": 24
            }
          }
        }
    }
  }
}

# %%
response = client.indices.create(index=index_name, body=index_body)

# %%
from streamlit_chat.modules.HyperClovaX import HyperClovaX
hcx = HyperClovaX(clova_studio_api_key=EMB_CONFIG['X-NCP-CLOVASTUDIO-API-KEY'], apigw_api_key=EMB_CONFIG['X-NCP-APIGW-API-KEY'])
hcx.set_embedding(app_id=EMB_CONFIG['APP_ID'], model_name=EMB_MODEL_NAME)

# %%
df_csv = pd.read_csv(filepath_or_buffer='streamlit_chat/data/starcraft2.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df_csv = pd.read_csv(filepath_or_buffer='스타크래프트2_키워드_수정_cp1.csv')
#
# File ~/vector-bemchmarks/vectirdb_edu2/.venv/lib/python3.8/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/vector-bemchmarks/vectirdb_edu2/.venv/lib/python3.8/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~/vector-bemchmarks/vectirdb_edu2/.venv/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~/vector-bemchmarks/vectirdb_edu2/.venv/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~/vector-bemchmarks/vectirdb_edu2/.venv/lib/python3.8/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '스타크래프트2_키워드_수정_cp1.csv'

# %%
origin_question = []
origin_text = []
embedding_text = []
# print(len(df['Completion']))
for idx, line in df_csv.iterrows():
    print(f"{idx + 1} / {len(df_csv['Completion'])}")
    res = hcx.embedding(text = line['Completion'])
    if res.status_code == 200:
        embedding_result = res.json()['result']['embedding']
        origin_question.append(line['Text'])
        origin_text.append(line['Completion'])
        embedding_text.append(embedding_result)
    else:
        print(f'error : {line["Completion"]}')
# Out:
# 1 / 246
# 2 / 246
# 3 / 246
# 4 / 246
# 5 / 246
# 6 / 246
# 7 / 246
# 8 / 246
# 9 / 246
# 10 / 246
# 11 / 246
# 12 / 246
# 13 / 246
# 14 / 246
# 15 / 246
# 16 / 246
# 17 / 246
# 18 / 246
# 19 / 246
# 20 / 246
# 21 / 246
# 22 / 246
# 23 / 246
# 24 / 246
# 25 / 246
# 212 / 246
# 213 / 246
# 214 / 246
# 215 / 246
# 216 / 246
# 217 / 246
# 218 / 246
# 219 / 246
# 220 / 246
# 221 / 246
# 222 / 246
# 223 / 246
# 224 / 246
# 225 / 246
# 226 / 246
# 227 / 246
# 228 / 246
# 229 / 246
# 230 / 246
# 231 / 246
# 232 / 246
# 233 / 246
# 234 / 246
# 235 / 246
# 236 / 246
# 237 / 246
# 238 / 246
# 239 / 246
# 240 / 246
# 241 / 246
# 242 / 246
# 243 / 246
# 244 / 246
# 245 / 246
# 246 / 246

# %%
if len(origin_text) == len(embedding_text):
    dt_dict = {'origin-question': origin_question, 'origin_text': origin_text, 'embedding_text': embedding_text}

    df_final = pd.DataFrame(dt_dict)

# %%
len(df_final)
# Out:
# 246

# %%
## bulk insert
sc2_datas = []
for idx, line in df_final.iterrows():
    # print(line['origin_text'])
    # index_no = '{ "index" : { "_index" : "' + index_name + '", "_id" : "' + str(idx + 1) + '" } }'
    # data = '{ "origin-text": "' + line['origin_text'] + '", "sc2-vector": ' + str(line['embedding_text']) + ' }'
    
    index_no = { "index" : { "_index" : index_name, "_id" : (idx + 1)} }
    data =  {"origin-question": line['origin-question'], "origin-text": line['origin_text'], "vector": line['embedding_text']}
    sc2_datas.append(index_no)
    sc2_datas.append(data)

# %%
client.bulk(sc2_datas)
# Out:
# {'took': 356,
#  'errors': False,
#  'items': [{'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '1',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '2',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 1,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '3',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 2,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '4',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 3,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '5',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 4,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '6',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 5,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '7',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 6,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '8',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 7,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '9',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 8,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '10',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 9,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '11',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 10,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '12',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 11,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '13',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 12,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '14',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 13,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '15',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 14,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '16',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 15,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '17',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 16,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '18',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 17,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '19',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 18,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '20',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 19,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '21',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 20,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '22',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 21,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '23',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 22,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '24',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 23,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '25',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 24,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '26',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 25,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '27',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 26,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '28',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 27,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '29',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 28,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '30',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 29,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '31',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 30,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '32',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 31,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '33',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 32,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '34',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 33,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '35',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 34,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '36',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 35,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '37',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 36,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '38',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 37,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '39',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 38,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '40',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 39,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '41',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 40,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '42',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 41,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '43',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 42,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '44',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 43,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '45',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 44,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '46',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 45,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '47',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 46,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '48',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 47,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '49',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 48,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '50',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 49,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '51',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 50,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '52',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 51,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '53',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 52,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '54',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 53,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '55',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 54,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '56',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 55,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '57',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 56,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '58',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 57,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '59',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 58,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '60',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 59,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '61',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 60,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '62',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 61,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '63',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 62,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '64',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 63,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '65',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 64,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '66',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 65,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '67',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 66,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '68',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 67,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '69',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 68,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '70',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 69,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '71',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 70,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '72',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 71,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '73',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 72,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '74',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 73,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '75',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 74,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '76',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 75,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '77',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 76,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '78',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 77,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '79',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 78,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '80',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 79,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '81',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 80,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '82',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 81,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '83',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 82,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '84',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 83,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '85',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 84,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '86',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 85,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '87',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 86,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '88',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 87,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '89',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 88,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '90',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 89,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '91',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 90,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '92',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 91,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '93',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 92,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '94',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 93,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '95',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 94,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '96',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 95,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '97',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 96,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '98',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 97,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '99',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 98,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id': '100',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 2, 'failed': 0},
#     '_seq_no': 99,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'ncp_edu_sc2-emb-test-index',
#     '_id':
.5868657, 0.02071708, 1.1117524, -0.59614855, -1.5847248, -0.07276299, 0.6648133, 0.679098, 1.2861465, -0.88529176, -1.4324723, -1.7981832, 1.1384428, 0.7299781, 1.5437238, 0.25220725, -0.35435262, 1.0914637, 0.49619403, 1.7353745, -0.3960627, 0.7309531, 0.18468334, -1.4469559, -0.7125714, -0.5963492, -0.41484654, 0.28179613, 0.2599132, -0.14882614, -0.39964592, -0.5087256, 0.15982893, -0.2385744, 1.5382545, -0.6931842, 0.7746714, -0.004390583, -0.683027, -1.0813718, 0.079081036, 0.15150827, 0.85519457, -0.2570498, -0.040215418, 0.140017, -1.5463727, -1.1420112, 0.2543295, -0.76442516, 1.0969528, 0.658427, -1.5237722, 1.5188721, 1.5418139, 0.003374563, -1.7868375, -0.28759414, -1.4083203, -1.0026072, 1.4461308, 0.8500093, -0.7000653, -0.22260405, -1.2874013, -1.6614884, 0.2885626, -0.7774016, -0.13222796, -0.11673268, -0.083722025, -0.1972186, -0.59037626, 0.005576308, -1.0991708, 0.89844805, -0.332829, -0.82688224, -1.4749508, -1.2074484, -0.8074913, 0.58776265, 0.97387946, 0.75988775, -0.14412566, 0.25085193, -0.7161193, 0.6306573, -0.17120598, -0.12938051, 0.21271281, 0.057970334, -1.1463678, -1.2226251, -1.2917014 ...

# %%
## Text Search
search_body_text_t = {
  "size": 10,
  "query": {
    "match": {
      "origin_text": query_text
    }
  }
}
search_result_text_t = client.search(index=index_name, body=search_body_text_t)
print(len(search_result_text_t["hits"]["hits"]))
for s_text_t in search_result_text_t["hits"]["hits"]:
    print(s_text_t)
    print(f"{s_text_t['_score']} | {s_text_t['_source']['origin-text']}")
# Out:
# 0

# %%
## Text Search
search_body_text_q = {
  "size": 10,
  "query": {
    "match": {
      "origin-question": query_text
    }
  }
}
search_result_text_q = client.search(index=index_name, body=search_body_text_q)
print(len(search_result_text_q["hits"]["hits"]))
for s_text_q in search_result_text_q["hits"]["hits"]:
    print(s_text_q)
    print(f"{s_text_q['_score']} | {s_text_q['_source']['origin-text']}")
# Out:
# 0

# %%
## Normal KNN
search_body = {
  "size": 15,
  "query": {
    "knn": {
      "vector": {
        "vector": query_text_emb,
        "k": 15
      }
    }
  }
}
search_result = client.search(index=index_name, body=search_body)
print(len(search_result["hits"]["hits"]))
for s in search_result["hits"]["hits"]:
    print(f"{s['_score']} | {s['_source']['origin-text']}")
# Out:
# ---------------------------------------------------------------------------
# RequestError                              Traceback (most recent call last)
# Cell In[388], line 13
#       1 ## Normal KNN
#       2 search_body = {
#       3   "size": 15,
#       4   "query": {
#    (...)
#      11   }
#      12 }
# ---> 13 search_result = client.search(index=index_name, body=search_body)
#      14 print(len(search_result["hits"]["hits"]))
#      15 for s in search_result["hits"]["hits"]:
#
# File ~/Documents/교육/파트너교육/HCX/.venv/lib/python3.11/site-packages/opensearchpy/client/utils.py:180, in query_params.<locals>._wrapper.<locals>._wrapped(*args, **kwargs)
#     177         if v is not None:
#     178             params[p] = _escape(v)
# --> 180 return func(*args, params=params, headers=headers, **kwargs)
#
# File ~/Documents/교육/파트너교육/HCX/.venv/lib/python3.11/site-packages/opensearchpy/client/__init__.py:1748, in OpenSearch.search(self, body, index, params, headers)
#    1745 if "from_" in params:
#    1746     params["from"] = params.pop("from_")
# -> 1748 return self.transport.perform_request(
#    1749     "POST",
#    1750     _make_path(index, "_search"),
#    1751     params=params,
#    1752     headers=headers,
#    1753     body=body,
#    1754 )
#
# File ~/Documents/교육/파트너교육/HCX/.venv/lib/python3.11/site-packages/opensearchpy/transport.py:447, in Transport.perform_request(self, method, url, params, body, timeout, ignore, headers)
#     445             raise e
#     446     else:
# --> 447         raise e
#     449 else:
#     450     # connection didn't fail, confirm its live status
#     451     self.connection_pool.mark_live(connection)
#
# File ~/Documents/교육/파트너교육/HCX/.venv/lib/python3.11/site-packages/opensearchpy/transport.py:408, in Transport.perform_request(self, method, url, params, body, timeout, ignore, headers)
#     405 connection = self.get_connection()
#     407 try:
# --> 408     status, headers_response, data = connection.perform_request(
#     409         method,
#     410         url,
#     411         params,
#     412         body,
#     413         headers=headers,
#     414         ignore=ignore,
#     415         timeout=timeout,
#     416     )
#     418     # Lowercase all the header names for consistency in accessing them.
#     419     headers_response = {
#     420         header.lower(): value for header, value in headers_response.items()
#     421     }
#
# File ~/Documents/교육/파트너교육/HCX/.venv/lib/python3.11/site-packages/opensearchpy/connection/http_urllib3.py:297, in Urllib3HttpConnection.perform_request(self, method, url, params, body, timeout, ignore, headers)
#     293 if not (200 <= response.status < 300) and response.status not in ignore:
#     294     self.log_request_fail(
#     295         method, full_url, url, orig_body, duration, response.status, raw_data
#     296     )
# --> 297     self._raise_error(
#     298         response.status,
#     299         raw_data,
#     300         self.get_response_headers(response).get("content-type"),
#     301     )
#     303 self.log_request_success(
#     304     method, full_url, url, orig_body, response.status, raw_data, duration
#     305 )
#     307 return response.status, response.headers, raw_data
#
# File ~/Documents/교육/파트너교육/HCX/.venv/lib/python3.11/site-packages/opensearchpy/connection/base.py:315, in Connection._raise_error(self, status_code, raw_data, content_type)
#     312 except (ValueError, TypeError) as err:
#     313     logger.warning("Undecodable raw error response from server: %s", err)
# --> 315 raise HTTP_EXCEPTIONS.get(status_code, TransportError)(
#     316     status_code, error_message, additional_info
#     317 )
#
# RequestError: RequestError(400, 'search_phase_execution_exception', "failed to create query: Field 'sc2-vector' is not knn_vector type.")

# %%
query_text = "바이킹의 공격력을 알려주세요"
query_text_emb = hcx.embedding(text=query_text)
query_text_emb = query_text_emb.json()['result']['embedding']

## Hybrid Search
search_body = {
  "_source": {
    "exclude": [
      "vector"
    ]
  },
  "query": {
    "hybrid": {
      "queries": [
        {
          "match": {
            "origin-question": {
              "query": query_text
            }
          }
        },
        {
          "match": {
            "origin_text": {
              "query": query_text
            }
          }
        },
        {
          "knn": {
            "vector": {
              "vector": query_text_emb,
              "k": 10
            }
          }
        }
      ]
    }
  },"size":10,
  "search_pipeline" : {
      "phase_results_processors": [
      {
        "normalization-processor": {
          "normalization": {
            "technique": "min_max"
          },
          "combination": {
            "technique": "arithmetic_mean",
            "parameters": {
              "weights": [
                0.2,
                0.1,
                0.7
              ]
            }
          }
        }
      }
    ]
  }
}
print(index_name)
# search_params = {
#     "search_pipeline" : "cw-nlp-search-pipeline"
# }
#search_result = client.search(index=index_name, body=search_body, params=search_params)

search_result = client.search(index=index_name, body=search_body)
print(len(search_result["hits"]["hits"]))
for s in search_result["hits"]["hits"]:
    print(f"{s['_score']} | {s['_source']['origin-text']}")
# Out:
# ncp_edu_sc2-emb-test-sss
# 10
# 0.75924915 | 바이킹은 높은 체력을 가진 기계 유닛으로 다양한 목적으로 사용 가능합니다.
# - 생명력 : 135
# - 방어력 : 0(+1)
# - 특성 : 중장갑-기계
# 0.7 | 바이킹은 3가지 적용 가능한 업그레이드가 있습니다.
# - 지능형 제어 장치 : 바이킹의 전투 모드를 빠르게 전환합니다.
# - 우주선 무기 업그레이드 1, 2, 3 단계 : 바이킹의 공격력을 증가시킵니다.
# - 차량 및 우주선 장갑 업그레이드 1, 2, 3 단계 : 바이킹의 방어력을 증가시킵니다.
# 0.6814124 | 바이킹은 두가지 기본 능력이 존재합니다.
# - 돌격 모드 : 바이킹을 돌격 모드로 전환합니다. 지상으로 이동하며 지상 목표물만 공격합니다.
# - 전투기 모드 : 바이킹을 전투기 모드로 전환합니다. 공중으로 이동하며 공중 목표물만 공격합니다.
# 0.66316986 | 바이킹의 공격 능력은 아래와 같습니다.
#
# 랜저 유도탄(Lanzer Torpedoes)을 사용하는 공중 공격 모드(전투기 모드)
# - 공격력 : 10(+1) x 2 / 중장갑 상대 : 14(+1) x 2
# - 사거리 : 9
# - 공격 속도 : 2(아주빠름 1.43)
# - 대상 : 공중 목표물
#
# 개틀링 포(Gatling Cannon)을 사용하는 지상 공격 모드(돌격 모드)
# - 공격력 : 12(+1) / 기계 상대 : 20(+2)
# - 사거리 : 6
# - 공격 속도 : 1(아주 빠름 기준 0.71)
# - 대상 : 지상 목표물
# 0.5636949 | 바이킹(Viking)은 스타크래프트2에 등장하는 테란 공중 유닛 입니다. 공중을 공격할 수 있는 전투기 모드와, 지상에 내려와 지상 유닛을 공격할 수 있는 돌격 모드 전환이 가능합니다.
# 0.34402 | 스타크래프트2에 등장하는 테란 공중유닛 정보를 알려드리겠습니다.
# - 바이킹(Viking) : 튼튼한 전투 지원기 입니다. 강력한 대주력함 공중 미사일을 탑재하고 있습니다. 돌격 모드로 변신하여 지상에 내려와 지상 유닛을 공격할 수 있습니다.
# - 벤시(Banshee) : 전술 타격기입니다. 은폐 업그레이드를 사용하여 은폐가 가능합니다.
# - 밤까마귀(Raven) : 공중 지원 유닛입니다. 자동 포탑 설치, 방해 매트릭스, 대장갑 미사일을 사용할 수 있습니다.
# - 의료선(Medivac) : 공중 수송기입니다. 주위 생체 유닛을 치료하며, 재연소 장치를 사용하여 빠른 이동이 가능합니다.
# - 전투순양함(Battlecruiser) : 강력한 군함입니다. 야마토 포와 전술 차원 도약을 사용할 수 있습니다.
# 0.25437447 | 반응로를 부착하면 유닛을 동시에 두기씩 생산할 수 있습니다.
#
# 병영 반응로
# - 해병, 사신 생산 가능
#
# 군수공장 반응로
# - 화염차, 화염기갑병, 땅거미지뢰 생산 가능
#
# 우주공항 반응로
# - 바이킹, 의료선, 해방선 생산 가능
# 0.13610543 | 밴시는 은폐를 사용하여 적의 공격을 회피할 수 있습니다. 다만 공중 공격은 불가능 하므로, 바이킹과 같은 호위 유닛이 필요합니다.
# - 생명력 : 140
# - 방어력 : 0(+1)
# - 특성 : 경장갑-기계
# 0.13192528 | 기술실을 부착할 경우 가능한 기능들을 자세히 알려드리겠습니다.
#
# 병영 기술실
# - 전투 방패 연구 : 해병의 체력이 10만큼 증가합니다.
# - 전투 자극제 연구 : 해병과 불곰이 전투 자극제를 사용할 수 있습니다. 전투 자극제를 사용한 유닛은 체력 피해를 빋지만, 짧은 시간 동안 공격 및 이동 속도가 증가합니다.
# - 충격탄 연구 : 대상의 움직임이 느려지도록 불곰의 무기를 업그레이드 합니다. 거대 유닛은 면역입니다.
# - 불곰 생산 : 병영에서 불곰의 생산이 가능해집니다.
# - 유령 생산 : 병영에서 유령의 생산이 가능해집니다. (유령 사관학교 필요)
#
# 군수 공장 기술실
# - 지옥불 조기점화기 연구 : 화염차가 경장갑 유닛에게 5의 추가 피해를 입힙니다. 화염기갑병이 경장갑 유닛에게 12의 추가 피해를 입힙니다.
# - 허리케인 추진기 연구 : 사이클론의 이도속도를 20% 향상시킵니다.
# - 천공 발톱 연구 : 땅거미 지뢰의 잠복 및 활성화 시간이 3배 더 빨라집니다.
# - 지능형 제어 장치 연구 : 화염차, 화염기갑병, 바이킹, 토르가 전투 모드를 빠르게 전환합니다.
# - 공성전차 생산 : 군수공장에서 밴시 생산이 가능해집니다.
# - 토르 생산 : 군수공장에서 토르 생산이 가능해집니다. (무기고 필요)
# - 사이클론 생산 : 군수공장에서 사이클론 생산이 가능해집니다.
#
# 우주공항 기술실
# - 은폐장 연구 : 밴시가 은폐 능력을 사용할 수 있습니다.
# - 초비행 회전날개 연구 : 밴시의 이동 속도가 증가합니다.
# - 방해 매트릭스 연구 : 밤까마귀가 방해 매트릭스를 사용할 수 있습니다.
# - 밴시 생산 : 우주공항에서 밴시 생산이 가능해집니다.
# - 밤까마귀 생산 : 우주공항에서 밤까마귀 생산이 가능해집니다.
# - 전투순양함 생산 : 우주공항에서 전투순양함 생산이 가능해집니다.(융합로 필요)
# 0.00070000003 | 파수기는 분열 광선(Disruption Beam)을 사용하여 지상 및 공중 목표물을 공격합니다.
# - 공격력 : 6(+1)
# - 사거리 : 5
# - 공격 속도 : 1(아주 빠름 기준 0.71)
# - 대상 : 지상 및 공중 목표물
